# %%
# Based on https://github.com/tex216/Missionaries-and-Cannibals/blob/master/main.py
from MCAgentquiz3 import MCAgent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Based on https://github.com/tex216/Missionaries-and-Cannibals/blob/master/main.py
# ----> 2 from MCAgentquiz3 import MCAgentquiz3
#
# ImportError: cannot import name 'MCAgentquiz3' from 'MCAgentquiz3' (/Users/alim/CSCE_580/Quiz3/MCAgentquiz3.py)

# %%
def test(missionaries_count, cannibals_count):
    #This will test your MCAgent with given initial test cases.
    test_agent = MCAgent()
    print (test_agent.solve(missionaries_count, cannibals_count))

# %%
# 1M, 1C
test(1, 1)
# Out:
# [(1, 1)]

# %%
# 2M, 2C
test(2, 2)
# Out:
# [(0, 2), (0, 1), (2, 0), (1, 0), (1, 1)]

# %%
# 3M, 3C
test(3, 3)
# Out:
# [(0, 2), (0, 1), (0, 2), (0, 1), (2, 0), (1, 1), (2, 0), (0, 1), (0, 2), (1, 0), (1, 1)]

# %%
# 4M, 3C
test(4, 3)
# Out:
# [(0, 2), (0, 1), (2, 0), (1, 0), (1, 1), (0, 1), (2, 0), (0, 1), (0, 2), (1, 0), (1, 1)]

# %%
# 5M, 3C
test(5, 3)
# Out:
# [(2, 0), (1, 0), (1, 1), (1, 0), (2, 0), (1, 0), (1, 1), (1, 0), (2, 0), (1, 0), (2, 0), (1, 0), (1, 1)]

# %%
# What happens - 2M, 3C ?
test(2, 3)
# Out:
# []
